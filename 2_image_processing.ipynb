# %%
import cv2 as cv

import matplotlib.pyplot as plt

img = cv.imread('0_data/dog_img1.jpg')
plt.imshow(img)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (350, 525, 3)

# %%
img.size
# Out:
# 551250
